# %%
import pandas as pd

# %%
c_df = pd.read_csv("../CSV Files/Core_Metrics_Zip_History.csv")
c_df.head()
# Out:
#   month_date_yyyymm  postal_code state      city_name  median_listing_price  \
# 0           2023-09        55127    MN     Saint Paul              635000.0
# 1           2023-09        18354    PA         Sciota              399999.0
# 2           2023-09        35593    AL           Vina              275000.0
# 3           2023-09        85295    AZ        Gilbert              625000.0
# 4           2023-09        94970    CA  Stinson Beach             7495000.0
#
#    median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                  -0.0483                  -0.0344                  53.0
# 1                   0.0000                   0.3560                   2.0
# 2                   0.1305                   0.7416                   1.0
# 3                  -0.0056                   0.0994                  72.0
# 4                   0.0000                  -0.2004                   2.0
#
#    active_listing_count_mm  active_listing_count_yy  ...  \
# ...

# %%
h_df = pd.read_csv("../CSV Files/Hotness_Metrics_Zip_History.csv")
h_df.head()
# Out:
#   month_date_yyyymm  postal_code state       city_name  nielsen_hh_rank  \
# 0           2023-09        14450    NY        Fairport            998.0
# 1           2023-09         4106    ME  South Portland           3627.0
# 2           2023-09        14624    NY       Rochester           1837.0
# 3           2023-09         6111    CT       Newington           3095.0
# 4           2023-09         1970    MA           Salem            884.0
#
#    hotness_rank  hotness_rank_mm  hotness_rank_yy  hotness_score  \
# 0           1.0             -5.0              0.0      99.978698
# 1           2.0             -2.0              NaN      99.923313
# 2           3.0             -4.0              1.0      99.919052
# 3           4.0          -1064.0            -15.0      99.897751
# 4           5.0             -7.0             -5.0      99.893490
#
#    supply_score  ...  median_dom_vs_us  ldp_unique_viewers_per_property_mm  \
# ...

# %%
c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2395931 entries, 0 to 2395930
# Data columns (total 42 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   month_date_yyyymm                        object
#  1   postal_code                              int64
#  2   state                                    object
#  3   city_name                                object
#  4   median_listing_price                     float64
#  5   median_listing_price_mm                  float64
#  6   median_listing_price_yy                  float64
#  7   active_listing_count                     float64
#  8   active_listing_count_mm                  float64
#  9   active_listing_count_yy                  float64
#  10  median_days_on_market                    float64
#  11  median_days_on_market_mm                 float64
#  12  median_days_on_market_yy                 float64
# ...

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 926158 entries, 0 to 926157
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   month_date_yyyymm                      926158 non-null  object
#  1   postal_code                            926158 non-null  int64
#  2   state                                  926158 non-null  object
#  3   city_name                              926158 non-null  object
#  4   nielsen_hh_rank                        926158 non-null  float64
#  5   hotness_rank                           926158 non-null  float64
#  6   hotness_rank_mm                        876941 non-null  float64
#  7   hotness_rank_yy                        688283 non-null  float64
#  8   hotness_score                          926158 non-null  float64
#  9   supply_score                           926158 non-null  float64
# ...

# %%
# merge the dataframes
combo_df = pd.merge(h_df, c_df, on=['postal_code', 'month_date_yyyymm'])

# %%
combo_df
# Out:
#        month_date_yyyymm  postal_code state_x     city_name_x  \
# 0                2023-09        14450      NY        Fairport
# 1                2023-09         4106      ME  South Portland
# 2                2023-09        14624      NY       Rochester
# 3                2023-09         6111      CT       Newington
# 4                2023-09         1970      MA           Salem
# ...                  ...          ...     ...             ...
# 926153           2017-08        10006      NY        New York
# 926154           2017-08        83113      WY       Big Piney
# 926155           2017-08        96024      CA    Douglas City
# 926156           2017-08        87829      NM         Quemado
# 926157           2017-08        36108      AL      Montgomery
#
#         nielsen_hh_rank  hotness_rank  hotness_rank_mm  hotness_rank_yy  \
# 0                 998.0           1.0             -5.0              0.0
# 1                3627.0           2.0             -2.0              NaN
# ...

# %%
combo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 926158 entries, 0 to 926157
# Data columns (total 66 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        926158 non-null  object
#  1   postal_code                              926158 non-null  int64
#  2   state_x                                  926158 non-null  object
#  3   city_name_x                              926158 non-null  object
#  4   nielsen_hh_rank                          926158 non-null  float64
#  5   hotness_rank                             926158 non-null  float64
#  6   hotness_rank_mm                          876941 non-null  float64
#  7   hotness_rank_yy                          688283 non-null  float64
#  8   hotness_score                            926158 non-null  float64
#  9   supply_score                             926158 non-null  float64
# ...

# %%
print(combo_df.columns)
# Out:
# Index(['month_date_yyyymm', 'postal_code', 'state_x', 'city_name_x',
#        'nielsen_hh_rank', 'hotness_rank', 'hotness_rank_mm', 'hotness_rank_yy',
#        'hotness_score', 'supply_score', 'demand_score',
#        'median_days_on_market_x', 'median_days_on_market_mm_x',
#        'median_dom_mm_day', 'median_days_on_market_yy_x', 'median_dom_yy_day',
#        'median_dom_vs_us', 'ldp_unique_viewers_per_property_mm',
#        'ldp_unique_viewers_per_property_yy',
#        'ldp_unique_viewers_per_property_vs_us', 'median_listing_price_x',
#        'median_listing_price_mm_x', 'median_listing_price_yy_x',
#        'median_listing_price_vs_us', 'quality_flag_x', 'county_name_x',
#        'state_y', 'city_name_y', 'median_listing_price_y',
#        'median_listing_price_mm_y', 'median_listing_price_yy_y',
#        'active_listing_count', 'active_listing_count_mm',
#        'active_listing_count_yy', 'median_days_on_market_y',
# ...

# %%
# delete duplicate columns shared by both dataframes
col_to_delete = ['county_name_x',
       'state_y', 'city_name_y', 'median_listing_price_y',
       'median_listing_price_mm_y', 'median_listing_price_yy_y', 'median_days_on_market_y',
       'median_days_on_market_mm_y', 'median_days_on_market_yy_y', 'quality_flag_y',
       'county_name_y']
combo_df = combo_df.drop(columns=col_to_delete)
combo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 926158 entries, 0 to 926157
# Data columns (total 55 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        926158 non-null  object
#  1   postal_code                              926158 non-null  int64
#  2   state_x                                  926158 non-null  object
#  3   city_name_x                              926158 non-null  object
#  4   nielsen_hh_rank                          926158 non-null  float64
#  5   hotness_rank                             926158 non-null  float64
#  6   hotness_rank_mm                          876941 non-null  float64
#  7   hotness_rank_yy                          688283 non-null  float64
#  8   hotness_score                            926158 non-null  float64
#  9   supply_score                             926158 non-null  float64
# ...

# %%
combo_df = combo_df.fillna(0)
combo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 926158 entries, 0 to 926157
# Data columns (total 55 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   month_date_yyyymm                        926158 non-null  object
#  1   postal_code                              926158 non-null  int64
#  2   state_x                                  926158 non-null  object
#  3   city_name_x                              926158 non-null  object
#  4   nielsen_hh_rank                          926158 non-null  float64
#  5   hotness_rank                             926158 non-null  float64
#  6   hotness_rank_mm                          926158 non-null  float64
#  7   hotness_rank_yy                          926158 non-null  float64
#  8   hotness_score                            926158 non-null  float64
#  9   supply_score                             926158 non-null  float64
# ...

# %%
print(combo_df.columns)
# Out:
# Index(['month_date_yyyymm', 'postal_code', 'state_x', 'city_name_x',
#        'nielsen_hh_rank', 'hotness_rank', 'hotness_rank_mm', 'hotness_rank_yy',
#        'hotness_score', 'supply_score', 'demand_score',
#        'median_days_on_market_x', 'median_days_on_market_mm_x',
#        'median_dom_mm_day', 'median_days_on_market_yy_x', 'median_dom_yy_day',
#        'median_dom_vs_us', 'ldp_unique_viewers_per_property_mm',
#        'ldp_unique_viewers_per_property_yy',
#        'ldp_unique_viewers_per_property_vs_us', 'median_listing_price_x',
#        'median_listing_price_mm_x', 'median_listing_price_yy_x',
#        'median_listing_price_vs_us', 'quality_flag_x', 'active_listing_count',
#        'active_listing_count_mm', 'active_listing_count_yy',
#        'new_listing_count', 'new_listing_count_mm', 'new_listing_count_yy',
#        'price_increased_count', 'price_increased_count_mm',
#        'price_increased_count_yy', 'price_reduced_count',
# ...

# %%
# create a new dataframe for only the ML necessary columns
# remove unnecessary columns
column_to_delete = ['quality_flag_x', 'median_listing_price_vs_us', 'median_dom_vs_us',
    'ldp_unique_viewers_per_property_mm', 'ldp_unique_viewers_per_property_yy', 
    'ldp_unique_viewers_per_property_vs_us', 'median_square_feet', 
    'median_square_feet_mm', 'median_square_feet_yy', 'state_x', 'city_name_x']

# delete colujns fro mthe dataframe
combo_df.drop(columns=column_to_delete, inplace=True)

combo_df.head()
# Out:
#   month_date_yyyymm  postal_code  nielsen_hh_rank  hotness_rank  \
# 0           2023-09        14450            998.0           1.0
# 1           2023-09         4106           3627.0           2.0
# 2           2023-09        14624           1837.0           3.0
# 3           2023-09         6111           3095.0           4.0
# 4           2023-09         1970            884.0           5.0
#
#    hotness_rank_mm  hotness_rank_yy  hotness_score  supply_score  \
# 0             -5.0              0.0      99.978698     99.974438
# 1             -2.0              0.0      99.923313     99.906271
# 2             -4.0              1.0      99.919052     99.965917
# 3          -1064.0            -15.0      99.897751     99.838105
# 4             -7.0             -5.0      99.893490     99.889230
#
#    demand_score  median_days_on_market_x  ...  \
# 0     99.982958                      7.0  ...
# 1     99.940354                      9.0  ...
# ...

# %%
# convert the month_date_yyyymm column to a date formate then convert to a reference point of months to the stating date
combo_df['month_date_yyyymm'] = pd.to_datetime(combo_df['month_date_yyyymm'],format='%Y-%m')

# determine the earliest date from the dataset
early_date = combo_df['month_date_yyyymm'].min()

# calculate the # of months since the earliest date
combo_df['months_since_reference'] = (
    (combo_df['month_date_yyyymm'].dt.year - early_date.year) * 12 +
    combo_df['month_date_yyyymm'].dt.month - early_date.month
)

combo_df.head(20)
# Out:
#    month_date_yyyymm  postal_code  nielsen_hh_rank  hotness_rank  \
# 0         2023-09-01        14450            998.0           1.0
# 1         2023-09-01         4106           3627.0           2.0
# 2         2023-09-01        14624           1837.0           3.0
# 3         2023-09-01         6111           3095.0           4.0
# 4         2023-09-01         1970            884.0           5.0
# 5         2023-09-01         1876           3610.0           6.0
# 6         2023-09-01        14617           4769.0           7.0
# 7         2023-09-01         1845           3507.0           8.0
# 8         2023-09-01         1960            340.0           9.0
# 9         2023-09-01         1915           1362.0          10.0
# 10        2023-09-01         3038           2723.0          11.0
# 11        2023-09-01         7043           8996.0          12.0
# 12        2023-09-01        43230            204.0          13.0
# ...

# %%
# double check beginning of data for month reference
combo_df.tail(20)
# Out:
#        month_date_yyyymm  postal_code  nielsen_hh_rank  hotness_rank  \
# 926138        2017-08-01        54832          26109.0       16066.0
# 926139        2017-08-01        24938          20804.0       16066.0
# 926140        2017-08-01        97869          21583.0       16069.0
# 926141        2017-08-01        38922          15072.0       16070.0
# 926142        2017-08-01        55708          22314.0       16071.0
# 926143        2017-08-01        85320          24261.0       16072.0
# 926144        2017-08-01        54527          22113.0       16073.0
# 926145        2017-08-01         7501           3809.0       16074.0
# 926146        2017-08-01        23432          20200.0       16075.0
# 926147        2017-08-01        39851          17976.0       16076.0
# 926148        2017-08-01        78361          13548.0       16078.0
# 926149        2017-08-01        27874          13772.0       16079.0
# 926150        2017-08-01        96041          16443.0       16081.0
# ...

# %%
combo_df.to_csv('../CSV Files/Combined_ML.csv', index=False)
